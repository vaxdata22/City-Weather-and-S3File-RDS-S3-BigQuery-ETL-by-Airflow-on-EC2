# %%
# Install the necessary package
pip install psycopg2

# %%
# Import the necessary libraries
import pandas as pd
import psycopg2
import warnings as wn

# %%
# Database credentials
db_user = "postgres"
db_password = "myRDSpassword"
db_host = "us-city-weather-data-etl-pipeline-database.cro6gemmugwm.eu-north-1.rds.amazonaws.com"
db_name = "us_city_weather_db"

# %%
# RDS Database connection parameters
conn_params = {
    "host": "us-city-weather-data-etl-pipeline-database.cro6gemmugwm.eu-north-1.rds.amazonaws.com",
    "database": "us_city_weather_db",
    "user": "postgres",
    "password": "myRDSpassword",
    "port": "5432"   # default Postgres port
}

# Create a connection
conn = psycopg2.connect(**conn_params)

# %%
# Suppress warnings
wn.filterwarnings('ignore')

# Run SQL query using Pandas
query = "SELECT * FROM houston_weather_data;"
df = pd.read_sql_query(query, conn)

# Display the DataFrame
df
# Out:
#    id     city description  temperature_fahrenheit  feels_like_fahrenheit  \
# 0   1  Houston   clear sky                  55.148                 53.654
#
#    min_temperature_fahrenheit  max_temperature_fahrenheit  pressure  humidity  \
# 0                      50.198                       57.11      1024        70
#
#    wind_speed      time_of_record             sunrise              sunset
# 0         0.0 2025-03-17 04:31:08 2025-03-17 07:28:35 2025-03-17 19:30:53

# %%
# Suppress warnings
wn.filterwarnings('ignore')

# Run SQL query using Pandas
query = "SELECT * FROM city_look_up;"
df = pd.read_sql_query(query, conn)

# Display the DataFrame
df
# Out:
#    id     city       state  census_2020  land_area_sq_mile_2020
# 0   1  Chicago    Illinois      2746388                   227.4
# 1   2  Seattle  Washington       737015                    83.8
# 2   3  Houston       Texas      2304580                   640.4

# %%
# Suppress warnings
wn.filterwarnings('ignore')

# To reset the houston_weather_data table
command = "TRUNCATE TABLE houston_weather_data RESTART IDENTITY;"
cur = conn.cursor()
cur.execute(command)
conn.commit()
cur.close()

# %%
# Suppress warnings
wn.filterwarnings('ignore')

# To reset the city_look_up table
command = "TRUNCATE TABLE city_look_up RESTART IDENTITY;"
cur = conn.cursor()
cur.execute(command)
conn.commit()
cur.close()

# %%
# Close the connection
conn.close()
